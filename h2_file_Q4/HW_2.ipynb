# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-varma/CS_415/blob/main/h2_file_Q4/HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
filename = 'left1.jpg'
img = cv2.imread(filename)
#cv2.imshow(img)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7F35EF7FCF10>

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=1024x683 at 0x7F35EDFA2E50>
